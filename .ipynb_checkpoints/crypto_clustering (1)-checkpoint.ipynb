# %% [markdown]
# # Clustering Crypto

# %%
# Initial imports
import requests
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import hvplot.pandas
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %% [markdown]
# ### Fetching Cryptocurrency Data

# %%
# Use the following endpoint to fetch json data
url = "https://min-api.cryptocompare.com/data/all/coinlist"

# %%
# Create a DataFrame 
# HINT: You will need to use the 'Data' key from the json response, then transpose the DataFrame.

# %%
# Alternatively, use the provided csv file:
# file_path = Path("Resources/crypto_data.csv")
file_path = Path("Data/crypto_data.csv")
# Create a DataFrame
crypto_df = pd.read_csv(file_path)
crypto_df.head(10)
# Out:
#   Unnamed: 0   CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0         42    42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 1        365    365Coin       X11       True   PoW/PoS              NaN
# 2        404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 3        611  SixEleven   SHA-256       True       PoW              NaN
# 4        808        808   SHA-256       True   PoW/PoS     0.000000e+00
# 5       1337  EliteCoin       X13       True   PoW/PoS     2.927942e+10
# 6       2015  2015 coin       X11       True   PoW/PoS              NaN
# 7        BTC    Bitcoin   SHA-256       True       PoW     1.792718e+07
# 8        ETH   Ethereum    Ethash       True       PoW     1.076842e+08
# 9        LTC   Litecoin    Scrypt       True       PoW     6.303924e+07
#
#   TotalCoinSupply
# 0              42
# 1      2300000000
# 2       532000000
# 3          611000
# 4               0
# 5    314159265359
# 6               0
# 7        21000000
# ...

# %% [markdown]
# ### Data Preprocessing

# %%
# Keep only necessary columns:
# 'CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply'
new_crypto_df = crypto_df.drop(["Unnamed: 0"], axis=1)
# = crypto_df[['CoinName', 'Algorithm', 'IsTrading', 'ProofType', 'TotalCoinsMined', 'TotalCoinSupply']]
new_crypto_df.head(10)
# Out:
#     CoinName Algorithm  IsTrading ProofType  TotalCoinsMined TotalCoinSupply
# 0    42 Coin    Scrypt       True   PoW/PoS     4.199995e+01              42
# 1    365Coin       X11       True   PoW/PoS              NaN      2300000000
# 2    404Coin    Scrypt       True   PoW/PoS     1.055185e+09       532000000
# 3  SixEleven   SHA-256       True       PoW              NaN          611000
# 4        808   SHA-256       True   PoW/PoS     0.000000e+00               0
# 5  EliteCoin       X13       True   PoW/PoS     2.927942e+10    314159265359
# 6  2015 coin       X11       True   PoW/PoS              NaN               0
# 7    Bitcoin   SHA-256       True       PoW     1.792718e+07        21000000
# 8   Ethereum    Ethash       True       PoW     1.076842e+08               0
# 9   Litecoin    Scrypt       True       PoW     6.303924e+07        84000000

# %%
# Keep only cryptocurrencies that are trading
trading_crypto_df = new_crypto_df.loc[crypto_df['IsTrading'] == True]
trading_crypto_df.tail(10)
# Out:
#          CoinName    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 1238       ZEPHYR      SHA-256       True      DPoS     2.000000e+09
# 1239     Quotient       Scrypt       True   PoW/PoS              NaN
# 1240  NetworkCoin          X13       True   PoW/PoS              NaN
# 1241   VapersCoin       Scrypt       True       PoW              NaN
# 1242      Gapcoin       Scrypt       True   PoW/PoS     1.493105e+07
# 1243   Super Zero       Ethash       True       PoW              NaN
# 1244          UOS      SHA-256       True      DPoI              NaN
# 1245       Beldex  CryptoNight       True       PoW     9.802226e+08
# 1246      Horizen     Equihash       True       PoW     7.296538e+06
# 1247  BitcoinPlus       Scrypt       True       PoS     1.283270e+05
#
#      TotalCoinSupply
# 1238      2000000000
# 1239               0
# 1240          400000
# 1241     42750000000
# 1242       250000000
# 1243      1000000000
# 1244      1000000000
# 1245      1400222610
# ...

# %% [markdown]
# # Remove the "IsTrading" column
# final_crypto_df = trading_crypto_df.drop(["IsTrading"], axis = 1)
# final_crypto_df.head(10)

# %%
# Remove rows with at least 1 null value
trading_crypto_df.dropna()
# Out:
#          CoinName    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0         42 Coin       Scrypt       True   PoW/PoS     4.199995e+01
# 2         404Coin       Scrypt       True   PoW/PoS     1.055185e+09
# 4             808      SHA-256       True   PoW/PoS     0.000000e+00
# 5       EliteCoin          X13       True   PoW/PoS     2.927942e+10
# 7         Bitcoin      SHA-256       True       PoW     1.792718e+07
# ...           ...          ...        ...       ...              ...
# 1238       ZEPHYR      SHA-256       True      DPoS     2.000000e+09
# 1242      Gapcoin       Scrypt       True   PoW/PoS     1.493105e+07
# 1245       Beldex  CryptoNight       True       PoW     9.802226e+08
# 1246      Horizen     Equihash       True       PoW     7.296538e+06
# 1247  BitcoinPlus       Scrypt       True       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 2          532000000
# 4                  0
# 5       314159265359
# 7           21000000
# ...

# %%
# Remove rows with cryptocurrencies having no coins mined
mined_crypto_df = trading_crypto_df.loc[trading_crypto_df["TotalCoinsMined"] != 0]
mined_crypto_df.head(10)
# Out:
#      CoinName Algorithm  IsTrading ProofType  TotalCoinsMined TotalCoinSupply
# 0     42 Coin    Scrypt       True   PoW/PoS     4.199995e+01              42
# 1     365Coin       X11       True   PoW/PoS              NaN      2300000000
# 2     404Coin    Scrypt       True   PoW/PoS     1.055185e+09       532000000
# 3   SixEleven   SHA-256       True       PoW              NaN          611000
# 5   EliteCoin       X13       True   PoW/PoS     2.927942e+10    314159265359
# 6   2015 coin       X11       True   PoW/PoS              NaN               0
# 7     Bitcoin   SHA-256       True       PoW     1.792718e+07        21000000
# 8    Ethereum    Ethash       True       PoW     1.076842e+08               0
# 9    Litecoin    Scrypt       True       PoW     6.303924e+07        84000000
# 10       Dash       X11       True   PoW/PoS     9.031294e+06        22000000

# %%
# Drop rows where there are 'N/A' text values
mined_crypto_df = mined_crypto_df[mined_crypto_df != 'N/A'].dropna()
mined_crypto_df.tail(10)
# Out:
#          CoinName    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 1226    TigerCash      SHA-256       True       PoS     1.000000e+09
# 1230        Waves   Leased POS       True      LPoS     1.000000e+08
# 1231      Particl          PoS       True       PoS     9.283138e+06
# 1234   BitTorrent        TRC10       True      DPoS     9.899887e+11
# 1237          Nxt          PoS       True  PoS/LPoS     1.000000e+09
# 1238       ZEPHYR      SHA-256       True      DPoS     2.000000e+09
# 1242      Gapcoin       Scrypt       True   PoW/PoS     1.493105e+07
# 1245       Beldex  CryptoNight       True       PoW     9.802226e+08
# 1246      Horizen     Equihash       True       PoW     7.296538e+06
# 1247  BitcoinPlus       Scrypt       True       PoS     1.283270e+05
#
#      TotalCoinSupply
# 1226      1000000000
# 1230       100000000
# 1231         8634140
# 1234    990000000000
# 1237      1000000000
# 1238      2000000000
# 1242       250000000
# 1245      1400222610
# ...

# %%
# Store the 'CoinName'column in its own DataFrame prior to dropping it from crypto_df
coins_name_df = mined_crypto_df['CoinName'].to_frame()
coins_name_df.head(10)
# Out:
#             CoinName
# 0            42 Coin
# 2            404Coin
# 5          EliteCoin
# 7            Bitcoin
# 8           Ethereum
# 9           Litecoin
# 10              Dash
# 11            Monero
# 12  Ethereum Classic
# 13             ZCash

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm
mined_crypto_df = mined_crypto_df.drop(['CoinName'], axis=1)
mined_crypto_df.tail(10)
# Out:
#         Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 1226      SHA-256       PoS     1.000000e+09      1000000000
# 1230   Leased POS      LPoS     1.000000e+08       100000000
# 1231          PoS       PoS     9.283138e+06         8634140
# 1234        TRC10      DPoS     9.899887e+11    990000000000
# 1237          PoS  PoS/LPoS     1.000000e+09      1000000000
# 1238      SHA-256      DPoS     2.000000e+09      2000000000
# 1242       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245  CryptoNight       PoW     9.802226e+08      1400222610
# 1246     Equihash       PoW     7.296538e+06        21000000
# 1247       Scrypt       PoS     1.283270e+05         1000000

# %%
# Create dummy variables for text features
X = pd.get_dummies(mined_crypto_df)
X
# Out:
#       IsTrading  TotalCoinsMined  CoinName_ ClubCoin  \
# 0          True     4.199995e+01                   0
# 2          True     1.055185e+09                   0
# 5          True     2.927942e+10                   0
# 7          True     1.792718e+07                   0
# 8          True     1.076842e+08                   0
# ...         ...              ...                 ...
# 1238       True     2.000000e+09                   0
# 1242       True     1.493105e+07                   0
# 1245       True     9.802226e+08                   0
# 1246       True     7.296538e+06                   0
# 1247       True     1.283270e+05                   0
#
#       CoinName_1717 Masonic Commemorative Token  CoinName_1Credit  \
# 0                                             0                 0
# 2                                             0                 0
# 5                                             0                 0
# ...

# %%
# Standardize data
X_scaled = StandardScaler().fit_transform(X)

# %% [markdown]
# ### Reducing Dimensions Using PCA

# %%
# Use PCA to reduce dimensions to 3 principal components
pca = PCA(n_components=3)

# %%
# Create a DataFrame with the principal components data
crypto_pca = pca.fit_transform(X_scaled)
pcs_df = pd.DataFrame(data= crypto_pca, columns=["PC 1", "PC 2, PC 3"]).reindex()
pcs_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3.x\envs\pyvizenv\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1675                     make_block(
# -> 1676                         values=blocks[0], placement=slice(0, len(axes[0])), ndim=2
#    1677                     )
#
# ~\anaconda3.x\envs\pyvizenv\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2741
# -> 2742     return klass(values, ndim=ndim, placement=placement)
#    2743
#
# ~\anaconda3.x\envs\pyvizenv\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#     142             raise ValueError(
# --> 143                 f"Wrong number of items passed {len(self.values)}, "
#     144                 f"placement implies {len(self.mgr_locs)}"
#
# ...

# %% [markdown]
# ### Clustering Crytocurrencies Using K-Means
#
# #### Find the Best Value for `k` Using the Elbow Curve

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(pcs_df)
    inertia.append(km.inertia_)

# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow.hvplot.line(x="k", y="inertia", xticks=k, title="Elbow Curve")

# %% [markdown]
# Running K-Means with `k=<your best value for k here>`

# %%
# Initialize the K-Means model

# Fit the model

# Predict clusters

# Create a new DataFrame including predicted clusters and cryptocurrencies features

# %% [markdown]
# ### Visualizing Results
#
# #### 3D-Scatter with Clusters

# %%
# Create a 3D-Scatter with the PCA data and the clusters

# %% [markdown]
# #### Table of Tradable Cryptocurrencies

# %%
# Table with tradable cryptos

# %%
# Print the total number of tradable cryptocurrencies

# %% [markdown]
# #### Scatter Plot with Tradable Cryptocurrencies

# %%
# Scale data to create the scatter plot

# %%
# Plot the scatter with x="TotalCoinsMined" and y="TotalCoinSupply"
